# %% [markdown]
# # Play by Play Analysis
# The following notebook uses play by play level data to compute the career stats of all players found in the data.
#
# The goal is to compute metrics in such a way as to take advantage of the play by play data. This will provide information for many analyses:
#
# - Player Lifetime Performance Model: A model that describes how a player's performance evolves as they age. First considering that they need to earn more opportunities as a function of their efficiency
# - player Performance Dynamics: A model that describes how a player performs conditional on their prior week, season, etc.
# - Player Lifetime Optimization Model: Using many inputs from other models, this one will help decide which players to draft when considering projections at the season level, and which ones to start considering projections at the weekly level. For the former, the lifetime performance model is a critical input because it determines how much volume a player will get given the conditions they find themselves in at the beggining of the season. The weekly dynamic model will do something similar, except that it is able to consider very recent information to adjust expectations for a player.

# %%
import pandas as pd

# %%
DataFrame = pd.read_csv("NFL_PBP_1999_2019.csv", nrows = 100)
DataFrame.head()
# Out:
#    Unnamed: 0  air_epa  air_wpa  air_yards  assist_tackle  \
# 0           0      NaN      NaN        NaN            0.0
# 1           1      NaN      NaN        NaN            0.0
# 2           2      NaN      NaN        NaN            0.0
# 3           3      NaN      NaN        NaN            0.0
# 4           4      NaN      NaN        NaN            0.0
#
#   assist_tackle_1_player_id assist_tackle_1_player_name assist_tackle_1_team  \
# 0                       NaN                         NaN                  NaN
# 1                       NaN                         NaN                  NaN
# 2                       NaN                         NaN                  NaN
# 3                       NaN                         NaN                  NaN
# 4                       NaN                         NaN                  NaN
#
#   assist_tackle_2_player_id assist_tackle_2_player_name  ...        wp  \
# 0                       NaN                         NaN  ...  0.000306
# 1                       NaN                         NaN  ...  0.542066
# 2                       NaN                         NaN  ...  0.506867
# 3                       NaN                         NaN  ...  0.496105
# 4                       NaN                         NaN  ...  0.476743
#
#         wpa  yac_epa  yac_wpa  yardline_100  yards_after_catch  yards_gained  \
# 0  0.541760      NaN      NaN          30.0                NaN           0.0
# 1 -0.035199      NaN      NaN          77.0                NaN           0.0
# 2 -0.010762      NaN      NaN          77.0                NaN           1.0
# 3 -0.019362      NaN      NaN          76.0                NaN           0.0
# 4  0.002985      NaN      NaN          81.0                NaN          10.0
#
#   ydsnet  ydstogo   yrdln
# 0    6.0        0  ARI 30
# 1    6.0       10  PHI 23
# 2    6.0       10  PHI 23
# 3    6.0        9  PHI 24
# 4    6.0       14  PHI 19
#
# [5 rows x 323 columns]

# %%
DataFrame[['pass','passer','receiver','rush','rusher','yards_gained','yards_after_catch','air_yards']]
# Out:
#     pass      passer    receiver  rush     rusher  yards_gained  \
# 0      0         NaN         NaN     0        NaN           0.0
# 1      1  D.Pederson    D.Staley     0        NaN           0.0
# 2      0         NaN         NaN     1   D.Staley           1.0
# 3      0         NaN         NaN     0        NaN           0.0
# 4      1  D.Pederson  B.Finneran     0        NaN          10.0
# ..   ...         ...         ...   ...        ...           ...
# 95     0         NaN         NaN     1  J.Plummer          10.0
# 96     0         NaN         NaN     0        NaN           0.0
# 97     1   J.Plummer   F.Sanders     0        NaN           0.0
# 98     1   J.Plummer     R.Moore     0        NaN           0.0
# 99     1    D.Staley         NaN     0        NaN          -8.0
#
#     yards_after_catch  air_yards
# 0                 NaN        NaN
# 1                 NaN        NaN
# 2                 NaN        NaN
# 3                 NaN        NaN
# 4                 NaN        NaN
# ..                ...        ...
# 95                NaN        NaN
# 96                NaN        NaN
# 97                NaN        NaN
# 98                NaN        NaN
# 99                NaN        NaN
#
# [100 rows x 8 columns]

# %%
pd.concat([DataFrame.iloc[:,DataFrame.columns.str.contains('player_id')],DataFrame.iloc[:,DataFrame.columns.str.contains('player_id')]])
# Out:
#    assist_tackle_1_player_id assist_tackle_2_player_id  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                        NaN                       NaN
# 3                        NaN                       NaN
# 4                        NaN                       NaN
# ..                       ...                       ...
# 95                       NaN                       NaN
# 96                       NaN                       NaN
# 97                       NaN                       NaN
# 98                       NaN                       NaN
# 99                       NaN                       NaN
#
#     assist_tackle_3_player_id  assist_tackle_4_player_id  blocked_player_id  \
# 0                         NaN                        NaN                NaN
# 1                         NaN                        NaN                NaN
# 2                         NaN                        NaN                NaN
# 3                         NaN                        NaN                NaN
# 4                         NaN                        NaN                NaN
# ..                        ...                        ...                ...
# 95                        NaN                        NaN                NaN
# 96                        NaN                        NaN                NaN
# 97                        NaN                        NaN                NaN
# 98                        NaN                        NaN                NaN
# 99                        NaN                        NaN                NaN
#
#    forced_fumble_player_1_player_id  forced_fumble_player_2_player_id  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
# ..                              ...                               ...
# 95                              NaN                               NaN
# 96                              NaN                               NaN
# 97                              NaN                               NaN
# 98                              NaN                               NaN
# 99                              NaN                               NaN
#
#    fumble_recovery_1_player_id  fumble_recovery_2_player_id  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
# ..                         ...                          ...
# 95                         NaN                          NaN
# 96                         NaN                          NaN
# 97                         NaN                          NaN
# 98                         NaN                          NaN
# 99                         NaN                          NaN
#
#    fumbled_1_player_id  ...  punt_returner_player_id punter_player_id  \
# 0                  NaN  ...                      NaN              NaN
# 1                  NaN  ...                      NaN              NaN
# 2                  NaN  ...                      NaN              NaN
# 3                  NaN  ...                      NaN              NaN
# 4                  NaN  ...                      NaN              NaN
# ..                 ...  ...                      ...              ...
# 95                 NaN  ...                      NaN              NaN
# 96                 NaN  ...                      NaN              NaN
# 97                 NaN  ...                      NaN              NaN
# 98                 NaN  ...                      NaN              NaN
# 99                 NaN  ...                      NaN              NaN
#
#    qb_hit_1_player_id qb_hit_2_player_id  receiver_player_id  \
# 0                 NaN                NaN                 NaN
# 1                 NaN                NaN          00-0015523
# 2                 NaN                NaN                 NaN
# 3                 NaN                NaN                 NaN
# 4                 NaN                NaN          00-0005231
# ..                ...                ...                 ...
# 95                NaN                NaN                 NaN
# 96                NaN                NaN                 NaN
# 97                NaN                NaN          00-0014328
# 98                NaN                NaN          00-0011601
# 99         00-0016976                NaN                 NaN
#
#     rusher_player_id  solo_tackle_1_player_id  solo_tackle_2_player_id  \
# 0                NaN               00-0014357                      NaN
# 1                NaN                      NaN                      NaN
# 2         00-0015523               00-0013644                      NaN
# 3                NaN                      NaN                      NaN
# 4                NaN               00-0009360                      NaN
# ..               ...                      ...                      ...
# 95        00-0013042               00-0016624                      NaN
# 96               NaN                      NaN                      NaN
# 97               NaN                      NaN                      NaN
# 98               NaN               00-0007660                      NaN
# 99               NaN               00-0016976                      NaN
#
#     tackle_for_loss_1_player_id  tackle_for_loss_2_player_id
# 0                           NaN                          NaN
# 1                           NaN                          NaN
# 2                           NaN                          NaN
# 3                           NaN                          NaN
# 4                           NaN                          NaN
# ..                          ...                          ...
# 95                          NaN                          NaN
# 96                          NaN                          NaN
# 97                          NaN                          NaN
# 98                          NaN                          NaN
# 99                   00-0016976                          NaN
#
# [100 rows x 35 columns]

# %%
DataFrame[['passer_player_id','passer_player_name']].drop_duplicates().dropna()
# Out:
#    passer_player_id passer_player_name
# 1        00-0012726         D.Pederson
# 8        00-0013042          J.Plummer
# 99       00-0015523           D.Staley

# %%
pd.DataFrame({"Column":DataFrame.columns}).to_excel("Columns.xlsx")

# %%
pd.DataFrame(DataFrame.columns[DataFrame.columns.str.contains('rush')].str.split("_").tolist())
# Out:
#           0          1       2     3
# 0     first       down    rush  None
# 1   lateral       rush    None  None
# 2   lateral     rusher  player    id
# 3   lateral     rusher  player  name
# 4      rush       None    None  None
# 5      rush    attempt    None  None
# 6      rush  touchdown    None  None
# 7    rusher       None    None  None
# 8    rusher         id    None  None
# 9    rusher     player      id  None
# 10   rusher     player    name  None
# 11    total       away    rush   epa
# 12    total       away    rush   wpa
# 13    total       home    rush   epa
# 14    total       home    rush   wpa

# %%
pd.DataFrame(DataFrame.columns[DataFrame.columns.str.contains('player_name')].str.split
